# %%
from selenium import webdriver
from selenium.webdriver.common.by import By  # selenium4의 명령문 구성내용
from bs4 import BeautifulSoup as bs
import time

# %%
browser = webdriver.Chrome()  # 크롬드라이버의 실행파일을 가리킴
browser.get('https://product.kyobobook.co.kr/detail/S000001890854')

# %%
pop_browser = browser.find_element(By.CLASS_NAME, 'btn_sm.btn_line_gray').click()

# %%
reg = browser.page_source
print(reg)
# Out:
# <html lang="ko" data-view="ink" data-service="product" class="kbb_loaded"><head><script type="text/javascript" async="" src="https://www.google-analytics.com/gtm/optimize-dyn.js?id=OPT-TXV7NFN&amp;cid=1719854086.1684720096&amp;cb=0.9401359180457394"></script><script src="https://connect.facebook.net/ko_KR/sdk.js?hash=fb8edb00ca4e6826bf4e545db6e45ef3" async="" crossorigin="anonymous"></script><script type="text/javascript" async="" src="https://www.googletagmanager.com/gtag/js?id=G-CQHKV7VZV7&amp;l=dataLayer&amp;cx=c"></script><script type="text/javascript" async="" src="https://www.googletagmanager.com/gtag/destination?id=G-CQHKV7VZV7&amp;l=dataLayer&amp;cx=c"></script><script type="text/javascript" id="www-widgetapi-script" src="https://www.youtube.com/s/player/e50626d8/www-widgetapi.vflset/www-widgetapi.js" async=""></script><script gtm="GTM-TWGDFSP" type="text/javascript" async="" src="https://www.googleoptimize.com/optimize.js?id=OPT-TXV7NFN"></script><script src="https://www.you
# ...
